# %%
import os
import dotenv
import requests

dotenv.load_dotenv()  # Load environment variables from .env file if it exists
# Ensure required environment variables are set
if not os.path.exists('.env'):
    print("Warning: .env file not found. Please create one with your credentials.")


# Load credentials from environment variables
CLIENT_ID = os.environ.get('GOVWIN_CLIENT_ID')
CLIENT_SECRET = os.environ.get('GOVWIN_CLIENT_SECRET')
USERNAME = os.environ.get('GOVWIN_USERNAME')
PASSWORD = os.environ.get('GOVWIN_PASSWORD')

# Check if all credentials are present
if not all([CLIENT_ID, CLIENT_SECRET, USERNAME, PASSWORD]):
    print("Error: Missing credentials. Please set environment variables:")
    print("  GOVWIN_CLIENT_ID, GOVWIN_CLIENT_SECRET, GOVWIN_USERNAME, GOVWIN_PASSWORD")
    exit(1)

# API endpoints
BASE_URL = "https://services.govwin.com"
TOKEN_URL = f"{BASE_URL}/neo-ws/oauth/token"

# Get access token
print("Testing connection to GovWin API...")
response = requests.post(
    TOKEN_URL,
    data={
        'client_id': CLIENT_ID,
        'client_secret': CLIENT_SECRET,
        'grant_type': 'password',
        'username': USERNAME,
        'password': PASSWORD,
        'scope': 'read'
    },
    headers={'Content-Type': 'application/x-www-form-urlencoded'}
)

if response.status_code == 200:
    token_data = response.json()
    access_token = token_data.get('access_token')
    print("✓ Successfully connected to GovWin API!")
    print(f"✓ Access token received (expires in {token_data.get('expires_in')} seconds)")
    
    # Test a simple API call
    test_response = requests.get(
        f"{BASE_URL}/neo-ws/opportunities",
        headers={'Authorization': f'Bearer {access_token}'},
        params={'max': 1}
    )
    
    if test_response.status_code == 200:
        print("✓ API call successful!")
    else:
        print(f"✗ API call failed: {test_response.status_code}")
else:
    print(f"✗ Authentication failed: {response.status_code}")
    print(f"Error: {response.text}")
# Out:
# Testing connection to GovWin API...
# ✓ Successfully connected to GovWin API!
# ✓ Access token received (expires in 43199 seconds)
# ✓ API call successful!

# %%
"""
search_personnel_security.py
Search GovWin opportunities that match:
    • Keyword    : "personnel security"
    • NAICS      : 541611, 561611, 541214
    • PSC / PSCs : R408, R703
Results are returned as JSON; the first page (max-100) is printed.
"""
import os
import sys
import time
import dotenv
import requests

dotenv.load_dotenv()                     # reads .env for the four creds
BASE_URL   = "https://services.govwin.com"
TOKEN_URL  = f"{BASE_URL}/neo-ws/oauth/token"
SEARCH_URL = f"{BASE_URL}/neo-ws/opportunities"

def get_access_token() -> str:
    """Password-grant OAuth2 (valid 12 h)."""
    rsp = requests.post(
        TOKEN_URL,
        data={
            "client_id":     os.getenv("GOVWIN_CLIENT_ID"),
            "client_secret": os.getenv("GOVWIN_CLIENT_SECRET"),
            "grant_type":    "password",
            "username":      os.getenv("GOVWIN_USERNAME"),
            "password":      os.getenv("GOVWIN_PASSWORD"),
            "scope":         "read",
        },
        headers={"Content-Type": "application/x-www-form-urlencoded"},
        timeout=20,
    )
    if rsp.status_code != 200:
        sys.exit(f"Auth failed {rsp.status_code}: {rsp.text}")
    token = rsp.json()
    expires = time.strftime("%Y-%m-%d %H:%M:%S", time.localtime(time.time()+token['expires_in']))
    print(f"✓ token OK – expires {expires}")
    return token["access_token"]

def search_opportunities(token: str):
    params = {
        # ---- search criteria ----
        "q": '"personnel security"',                # exact phrase search
        "max": 100,     # up to 100 per page (default 10) :contentReference[oaicite:2]{index=2}
        "offset": 0,
    }

    rsp = requests.get(
        SEARCH_URL,
        headers={"Authorization": f"Bearer {token}"},
        params=params,
        timeout=20,
    )
    if rsp.status_code != 200:
        sys.exit(f"Search failed {rsp.status_code}: {rsp.text}")

    data = rsp.json()
    print(f"Found {data['meta']['paging']['totalCount']} matching opportunities\n")
    # pretty-print the first few titles
    for opp in data.get("opportunities", [])[:5]:
        print(f"{opp['id']:>10}  {opp['title']}")
    # full JSON is still in `data`

if __name__ == "__main__":
    access_token = get_access_token()
    search_opportunities(access_token)
# Out:
# ✓ token OK – expires 2025-06-22 08:05:02
# Found 3 matching opportunities
#
#  OPP253641  PERSONNEL SECURITY SUPPORT SERVICES
#  OPP253037  INFORMATION TECHNOLOGY ARTIFICIAL INTELLIGENCE MACHINE LEARNING PROGRAMMATIC SUPPORT SERVICES (IT)(AI)
# FBO4026782  Multi-Function Device (MFD) Lease Agreement and PM; to include: Lease, Maintenance, and Overages.

# %%
'GSA eBuy tests'

import os, time, requests, dotenv, datetime as dt
from pprint import pprint              # nice console preview

dotenv.load_dotenv()                   # GOVWIN_* creds in .env
BASE_URL   = "https://services.govwin.com"
TOKEN_URL  = f"{BASE_URL}/neo-ws/oauth/token"
SEARCH_URL = f"{BASE_URL}/neo-ws/opportunities"

def get_access_token() -> str:
    rsp = requests.post(
        TOKEN_URL,
        data={
            "client_id":     os.getenv("GOVWIN_CLIENT_ID"),
            "client_secret": os.getenv("GOVWIN_CLIENT_SECRET"),
            "grant_type":    "password",
            "username":      os.getenv("GOVWIN_USERNAME"),
            "password":      os.getenv("GOVWIN_PASSWORD"),
            "scope":         "read",
        },
        timeout=20,
    )
    rsp.raise_for_status()
    token = rsp.json()
    expires = time.strftime("%Y-%m-%d %H:%M:%S",
                            time.localtime(time.time() + token["expires_in"]))
    print(f"✓ token OK – expires {expires}")
    return token["access_token"]

def search_tns(token: str,
               keyword: str = '"personnel "',
               lookback_days: int = 10,
               max_per_page: int = 100):
    date_from = (dt.datetime.utcnow() - dt.timedelta(days=lookback_days)).strftime("%Y-%m-%d")
    headers = {"Authorization": f"Bearer {token}"}
    params = {
        "q": keyword,
        "market": "Federal",
        "oppType": "TNS",               # ← Task-Order Notices
        "oppSelectionDateFrom": date_from,
        "max": max_per_page,
        "offset": 0,
    }

    all_rows = []
    while True:
        rsp = requests.get(SEARCH_URL, headers=headers, params=params, timeout=20)
        rsp.raise_for_status()
        page = rsp.json().get("opportunities", [])
        all_rows.extend(page)

        print(f"Fetched {len(page):3d} rows  (offset {params['offset']})")
        if len(page) < max_per_page:           # last page reached
            break
        params["offset"] += len(page)

    print(f"\nTotal TNS rows returned: {len(all_rows)}")
    for opp in all_rows[:5]:
        print(f"{opp['id']:>10}  {opp['title'][:90]}")

    return all_rows

if __name__ == "__main__":
    token = get_access_token()
    tns_data = search_tns(token)
# Out:
# ✓ token OK – expires 2025-06-22 08:05:03
# Fetched   1 rows  (offset 0)
#
# Total TNS rows returned: 1
# TNS2244465  ADMINISTRATIVE PERSONNEL INVESTIGATIONS MISCONDUCT AND/OR HARASSMENT (HR) - BPA

# %%
'Tracked Opportunities'

import os, time, requests, dotenv, datetime as dt
from pprint import pprint              # optional pretty preview

dotenv.load_dotenv()                   # GOVWIN_* creds in .env
BASE_URL   = "https://services.govwin.com"
TOKEN_URL  = f"{BASE_URL}/neo-ws/oauth/token"
SEARCH_URL = f"{BASE_URL}/neo-ws/opportunities"


def get_access_token() -> str:
    rsp = requests.post(
        TOKEN_URL,
        data={
            "client_id":     os.getenv("GOVWIN_CLIENT_ID"),
            "client_secret": os.getenv("GOVWIN_CLIENT_SECRET"),
            "grant_type":    "password",
            "username":      os.getenv("GOVWIN_USERNAME"),
            "password":      os.getenv("GOVWIN_PASSWORD"),
            "scope":         "read",
        },
        timeout=20,
    )
    rsp.raise_for_status()
    tok = rsp.json()
    print("✓ token OK – expires", time.strftime(
        "%Y-%m-%d %H:%M:%S",
        time.localtime(time.time() + tok["expires_in"])
    ))
    return tok["access_token"]


def search_tracked(
        token: str,
        keyword: str = '"personnel"',
        lookback_days: int = 9,
        max_per_page: int = 100,
    ):
    """Fetch analyst-curated tracked opportunities (oppType=OPP)."""
    date_from = (dt.datetime.utcnow() - dt.timedelta(days=lookback_days)
                ).strftime("%Y-%m-%d")

    headers = {"Authorization": f"Bearer {token}"}
    params = {
        "q": keyword,
        "market": "Federal",       # drop if you need state-&-local too
        "oppType": "TNS,OPP",          # ← tracked opps
        "oppSelectionDateFrom": date_from,
        "max": max_per_page,
        "offset": 0,
    }

    rows = []
    while True:
        rsp = requests.get(SEARCH_URL, headers=headers,
                           params=params, timeout=20)
        rsp.raise_for_status()
        page = rsp.json().get("opportunities", [])
        rows.extend(page)

        print(f"Fetched {len(page):3d}  (offset {params['offset']})")
        if len(page) < max_per_page:
            break
        params["offset"] += len(page)

    print(f"\nTotal OPP rows returned: {len(rows)}")
    for opp in rows:
        print(f"{opp['id']:>10}  {opp['title'][:90]}")
    return rows


if __name__ == "__main__":
    tok = get_access_token()
    opp_data = search_tracked(tok)
# Out:
# ✓ token OK – expires 2025-06-22 08:05:03
# Fetched 100  (offset 0)
# Fetched 100  (offset 100)
# Fetched 100  (offset 200)
# Fetched  95  (offset 300)
#
# Total OPP rows returned: 395
#  OPP250776  COBOL DATABASE MODERNIZATION
#  OPP253641  PERSONNEL SECURITY SUPPORT SERVICES
#  OPP222941  DEFENSE READINESS REPORTING SYSTEM STRATEGIC MODERNIZATION (DRRS-S)
#  OPP255678  DCPAS FITNESS CENTER AND HEALTH PROMOTION SERVICES
#  OPP242553  MILITARY COMMUNITY AND FAMILY POLICY OUTREACH  DIGITAL ENTERPRISE SERVICES III (MCFP)(MODE
#  OPP246272  FY25 CONTRACTOR SUPPORT PERSONNEL PM BM AND PA
#  OPP224890  FACILITY ENGINEERING OPERATIONS AND MAINTENANCE AND CONFERENCE SUPPORT SERVICES FOR FEDERA
#  OPP201927  CENSUS INTEGRATED PERSONNEL AND PAYROLL SYSTEM (CIPPS)
#  OPP244722  DPAC MARKET RESEARCH AND STUDIES SURVEY SERVICES
#  OPP241524  TAILORING SERVICES FOR ACCESSION PERSONNEL USCG TRAINING CENTER CAPE MAY NJ
#  OPP227404  NATIONAL YOUTH CHALLENGE PROGRAM AND THE DEPARTMENT OF DEFENSE STARBASE PROGRAM
#  OPP225841  DYNAMIC AUTOMATED RESOURCE TRACKING (DART)
# TNS2244465  ADMINISTRATIVE PERSONNEL INVESTIGATIONS MISCONDUCT AND/OR HARASSMENT (HR) - BPA
#  OPP242155  ATC MOBILE AL GALLEY AND HOUSEKEEPING SERVICES
#  OPP220896  US ARMY GARRISON SUPPORT SERVICES  FORT KNOX
#  OPP255782  US ARMY GARRISON SUPPORT SERVICES  FORT KNOX
#  OPP251872  HUMAN CENTERED DESIGN SUPPORT (HCD)
#  OPP236228  SPECIAL OPERATIONS FORCES PERSONNEL RECOVERY FIXED WING SUSTAINMENT ENGINEERING SUPPORT (S
#  OPP255515  FIELD BACKGROUND INVESTIGATIVE SERVICES
#  OPP242139  SOCCENT INTELLIGENCE SERVICES SUPPORT CONTRACT
#  OPP250459  AEC NIH GROUNDS MAINTENANCE
#  OPP212461  HELICOPTER FLIGHT SERVICES IN SUPPORT OF DOI ALASKA USING SMALL MEDIUM TURBINE
#  OPP238616  CLOUD APPLICATION FOR SECURITY INFORMATION SYSTEM (SAAS)(MCCS)
#  OPP255780  DEA DISASTER READINESS COURSE ESF13 (ESF13)
#  OPP253571  VARIABLE REFRIGERANT FLOW SYSTEM SUPPORT SERVICES (VRF)
#  OPP255529  SUPERIOR COURT GRAND JURY COURT REPORTING SERVICES FOR THE UNITED STATES ATTORNEYS OFFICE
#  OPP253707  RECRUIT HIRE AND ADMINISTER PSCS
#  OPP216079  PSCFOH INFORMATION TECHNOLOGY STAFFING SUPPORT SERVICES
#  OPP245586  COCO INTELLIGENCE SURVEILLANCE AND RECONNAISSANCE SERVICES (ISR)
#  OPP240536  VENTI MULTIPLE AWARD CONSTRUCTION CONTRACT VENTI MACC
#  OPP255721  UNITED STATES SPECIAL OPERATIONS COMMAND RESOURCE MANAGEMENT SYSTEM
#  OPP255629  SECURITY ADMINISTRATIVE SUPPORT SERVICES
#  OPP249781  POSTAL SERVICE IN JOINT BASE LEWIS MCCHORD WA
#  OPP213329  MARINE RECONNAISSANCE VEHICLE TRAINING (MRV)
#  OPP252638  BUSINESS CORPORATE AND COMMAND OPERATIONS SUPPORT SERVICES (SEAPORT NXG)
#  OPP238674  CYBER OPERATIONS  SYSTEMS ENGINEERING AND TECHNICAL ASSISTANCE (COSETA)
#  OPP250551  FLYING SQUADRON FUNCTION SUPPORT
#  OPP253183  PLANNING AND ESTIMATING SUPPORT SERVICES (SEAPORT NXG)
#  OPP186921  PUERTO RICO ENGINEERING SUPPORT
#  OPP208814  LOCAL GUARD SERVICES FREETOWN SIERRA LEONE
#  OPP255610  AGENCIES NURSE STAFFING SUPPORT SERVICES DEFENSE FINANCE ACCOUNTING SERVICES AGENCIES
#  OPP204185  BUREAU OF DIPLOMATIC SECURITY COURIER SUPPORT SERVICES
#  OPP208578  LOCAL GUARD SERVICES VIENNA AUSTRIA
#  OPP206123  HOMEOWERSHIP CENTER AND HEADQUARTER ACCESS TO COMPREHENSIVE INFORMATION FOR OFFICE OF LEND
#  OPP245957  TRANSPORTATION SERVICES
#  OPP251282  ADVANCED WEAPONS TRAINING SUPPORT SERVICES
#  OPP237871  MEDIUM MULTIPLE AWARD CONSTRUCTION CONTRACT FOR THE NAVFAC SOUTHEAST AREA OF OPERATIONS
#  OPP255752  USAFCENT POSTAL OPERATIONS
#  OPP211440  JANITORIAL SERVICES FOR THE MISSION IN BOGOTA COLOMBIA
#  OPP246100  VISIT BOARD SEARCH AND SEIZURE
#  OPP250486  LOCAL GUARD SERVICES RABAT MOROCCO
#  OPP252266  WIRELESS SYSTEMS MAINTENANCE SERVICES (WSMS)
#  OPP240049  P8 C40 CETS
#  OPP206410  REPLACEMENT ENVIRONMENTAL QUALITY SERVICES AT YAKIMA TRAINING CENTER WA (EQ)
#  OPP251953  WORK RECEPTION COMPUTER AIDED DESIGN AND DRAFTING GEOGRAPHIC INFORMATION SYSTEMS SERVICES
#  OPP225077  FUELS AND SUPPLY SERVICES
#  OPP252387  JANITORIAL SERVICES US COAST GUARD SECTOR SAN DIEGO
#  OPP252181  DHS CWMD MOBILE DETECTION DEPLOYMENT PROGRAM (MDDP)
#  OPP207262  BAY AREA HOUSING AND GROUNDS MAINTENANCE SERVICES
#  OPP233358  ARMED PROTECTIVE SECURITY OFFICER SERVICES AT PLUM ISLAND ANIMAL DISEASE CENTER (PSO PIADC
#  OPP255793  MESS ATTENDANT SERVICES SILVER DOLPHIN BISTRO
#  OPP253140  ADVISORY ASSISTANCE SERVICES COUNTERING WEAPONS OF MASS DESTRUCTION OFFICE POLICY PLANS AN
#  OPP238307  USAFRICOM DEDICATED PASSENGER AIR CHARTER SERVICE
#  OPP193942  AEC DFAS ELEVATOR MAINTENANCE SERVICE
#  OPP216240  USACE OPERATION AND MAINTENANCE SERVICES AT THE JOHN H KERR DAM AND RESERVOIR IN VIRGINIA
#  OPP186498  MESS ATTENDANT SERVICES SILVER DOLPHIN BISTRO
#  OPP252951  EHCM MODERNIZATION SYSTEM INTEGRATOR SERVICES
#  OPP200703  LOCAL GUARD SERVICES FOR US MISSION NIGERIA (LGS)
#  OPP219855  USPFO FOR WISCONSIN CASE MANAGEMENT MEDICAL RECORDS SERVICES
#  OPP225773  PHYSICAL SECURITY INFORMATION MANAGEMENT SYSTEM (PSIM)
#  OPP225787  WASTE AND REFUSE COLLECTION SERVICES GULF COAST VETERANS HEALTH CARE SYSTEM
#  OPP255788  JANITORIAL SERVICES FOR FAA WISCONSIN 8 ATCT FACILITIES
#  OPP255766  BOILER REPLACEMENT AT B2412
#  OPP253449  AFICA MEDICAL READINESS AND LOGISTICS PROGRAM SUPPORT (MEFPAK ECME)
#  OPP238540  ELECTRONIC SECURITY SYSTEMS  MAINTENANCE ON THE FORT CAVAZOS TX INSTALLATION (ESS)
#  OPP255732  OSHA DEP EXPERT WITNESS AND ENFORCEMENT RELATED COMPLIANCE
#  OPP254980  INFORMATION SYSTEMS AND NETWORK SUPPORT
#  OPP244656  SHELF STOCKING RECEIVING STORAGE HOLDING AREA AND CUSTODIAL OPERATIONS FORT MEADE COMMISSA
#  OPP255738  FACIAL CAPTURE AND PROCESSING
#  OPP255645  USAWOCC INSTITUTION CONTRACT INSTRUCTORS
#  OPP224277  UNIFORM EQUIPMENT ISSUE AND LAUNDRY SERVICES
#  OPP254858  DLA J34 RETAIL INTEGRATION SUPPORT
#  OPP255781  MSC QUALIFIED MEMBER OF THE ENGINE DEPARTMENT QMED TRAINING
#  OPP255703  RENOVATE EAST WING OF BUILDING 401 AT JBLE VA
#  OPP240931  HUMAN RESOURCES TRAINING BPA SET UP
#  OPP254363  INFORMATION TECHNOLOGY SUPPORT SERVICES FOR THE DEPARTMENT OF HOMELAND SECURITY TRANSPORTA
#  OPP249695  SAF FME WORKFORCE DEVELOPMENT AND EXECUTIVE SUPPORT
#  OPP250966  ENTERPRISE INTEGRATION MODERNIZATION AND PROGRAM SUPPORT SERVICES FOR THE OFFICE OF CIVIL
#  OPP254884  SHELF STOCKING RECEIVING STORAGE HOLDING AREA AND CUSTODIAL SERVICES AT THE JBA BOLLING AF
#  OPP253666  GREATER ATLANTIC REGIONAL FISHERIES INFORMATION TECHNOLOGY (GARFIT 3)
#  OPP243417  JANITORIAL SERVICES AT THE NEW US CONSULATE COMPOUND ON MASIF ROAD
#  OPP253954  COMPUTER ROOM AIR CONDITIONING MAINTENANCE REPAIRS AND REPLACEMENT (CRAC II)
#  OPP234987  MESS ATTENDANT SERVICES AT HURLBURT FIELD (HURLBURT MESS)
#  OPP236064  PEC STRATEGIC EDUCATION AND INSTRUCTOR SUPPORT SERVICES
#  OPP241237  UNITED STATES ARMY ENVIRONMENTAL COMMAND CLEANUP SUPPORT SERVICES MULTIPLE LOCATIONS
#  OPP205215  POSTWIDE CUSTODIAL SERVICES ON JOINT BASE MYER HENDERSON HALL
#  OPP219858  INTEGRATED BEHAVIORAL HEALTH SERVICES TO RESERVE COMPONENT SERVICE MEMBERS
#  OPP255586  LOW EARTH ORBIT SATELLITE RENTAL SERVICES (LEO)
#  OPP255614  JANITORIAL SERVICES FOR GREAT LAKES NATIONAL CEMETERY
#  OPP255803  PEC STRATEGIC EDUCATION AND INSTRUCTOR SUPPORT SERVICES
#  OPP255729  LOCAL GUARD SERVICES US MISSION WINDHOEK NAMIBIA
#  OPP235375  JANITORIAL SERVICES FOR THE FLORIDA NATIONAL CEMETERY BUSHNELL FL
#  OPP197008  WELDING INSTRUCTION SUPPORT SERVICES (SEAPORT NXG)
#  OPP195369  GRAND FORKS AIR FORCE BASE AIRFIELD PAVING IDIQ
#  OPP213771  COURT REPORTING SERVICES
#  OPP207233  JANITORIAL SERVICES FOR GREAT LAKES NATIONAL CEMETERY
#  OPP237724  ADVISORY AND ASSISTANCE SERVICES  COUNTERING WEAPONS OF MASS DESTRUCTION OFFICE OPERATIONS
#  OPP255603  ACU5 WELDING INSTRUCTION SERVICES (SEAPORT NXG)
#  OPP235023  23 FTE NURSING ASSISTANTS FOR THE VA PALO ALTO HEALTH CARE SYSTEM CA (VAPAHCS)
#  OPP252833  GROUND AMBULANCE SERVICE FOR ST CLOUD VA HEALTH CARE SYSTEM
#  OPP233102  PROTECTIVE COATINGS AND MARKINGS CONSTRUCTION SERVICES
#  OPP241598  HANGAR DOOR MAINTENANCE REPAIR SERVICES AT CANNON AFB
#  OPP238617  JANITORIAL SERVICES FOR US EMBASSY VALLETTA MALTA
#  OPP223384  FEMA NATIONAL CROSS DOCK AND INCIDENT BASE SUPPORT CONTRACT
#  OPP222463  DARK FIBER SERVICES FOR AUGUSTA GEORGIA AND KNOXVILLE TENNESSEE
#  OPP220835  SUPPORT SHIP FOR NAVAL SURFACE WARFARE CENTER  PANAMA CITY
#  OPP250376  ARMORED CAR AND ARMED GUARD SERVICE
#  OPP240327  POINT MUGU PASSENGER AIR TRANSPORTATION SERVICES (PMPATS)
#  OPP209789  GROUNDS MAINTENANCE SERVICES AT FORT CAVAZOS TEXAS
#  OPP250435  ADMINISTRATIVE ASSISTANTS TO SUPPORT THE METC MUNITIONS SYSTEMS DIRECTORATE IN PICATINNY A
#  OPP238126  MARINE ROTATIONAL FORCE DARWIN AUSTRALIA (MRF-D)
#  OPP240623  ACF DEA LIHEAP AND TTA
#  OPP255727  SPECIAL SECURITY OFFICERS FOR SENSITIVE COMPARTMENTED INFORMATION SECURITY MANAGEMENT FOR
#  OPP255353  CONSTRUCTION PROJECT FOR CHILD DEVELOPMENT CENTER IN THE STATE OF CALIFORNIA SAN DIEGO CAL
#  OPP236510  CONSTRUCTION MULTIPLE AWARD CONTRACT (C-MAC)
#  OPP251906  EDUCATION SERVICES FOR PK12 STUDENTS AT HANSCOM AFB MA
#  OPP217365  BUILDING MAINTENANCE SERVICES US CONSULATE GENERAL OSAKA JAPAN
#  OPP253755  AIR FORCE DRUG TESTING LABORATORY MEDICAL WASTE AND PERSONAL IDENTIFIABLE INFORMATION DISP
#  OPP220032  CONSTRUCTION SERVICES IN SUPPORT OF THE USDA ARS DAIRY FORAGE RESEARCH CENTER AT PRAIRIE D
#  OPP250716  GROUNDS MAINTENANCE AND LANDSCAPING SERVICES NSWC IHD
#  OPP254098  INTEGRATED SOLID WASTE RECYCLING PAVEMENT CLEARANCE SERVICES AT ANDERSEN AFB GUAM
#  OPP252517  WRONG WAY DETECTION
#  OPP245279  MAPSS QUALITY AND MISSION ASSURANCE (TRANCHE 1)
#  OPP250922  FINANCIAL SUPPORT SERVICES
#  OPP234583  CONTRACTOR SPECIALIZED SECURITY OFFICER (CSSO)
#  OPP255802  SOLID WASTE MANAGEMENT COLLECTION AND DISPOSAL RECYCLING OAHU HAWAII
#  OPP241699  11 METER RIGID HULL INFLATABLE BOAT TRAILER GALVANIZED (RHIB)
#  OPP254646  USACE AEC CONSTRUCT UEPH BARRACKS FORT STEWART GA
#  OPP255139  WEB SHAREPOINT MICROSOFT OFFICE APPLICATIONS ADOBE CREATIVE CLOUD APPLICATIONS AND GRAPHIC
#  OPP230378  PASSENGER TERMINAL SECURITY AND BAGGAGE SCREENING SERVICES
#  OPP240924  ENGINEERING SUPPORT FOR MARSHALL SPACE FLIGHT CENTER OFFICES DEPARTMENTS AND DIRECTORATES
#  OPP238174  SUBSISTENCE PRIME VENDOR NORTHERN EUROPE (SVP)
#  OPP236173  NATIONAL AIRSPACE SYSTEM ENGINEERING AND SUPPORT SERVICES (NAS)
#  OPP234780  SOLID WASTE MANAGEMENT COLLECTION AND DISPOSAL RECYCLING OAHU HAWAII
#  OPP254437  ARMED FORCES RECRUITING JANITORIAL SERVICES MATOC MULTIPLE LOCATIONS
#  OPP254626  INTERNATIONAL REGULATORY ASSISTANCE WITH RADIOACTIVE SOURCES AND URANIUM RECOVERY PROJECTS
#  OPP247784  AVIATION FIELDING AND SUSTAINMENT MAINTENANCE SUPPORT SERVICES ROYAL SAUDI LAND FORCES AVI
#  OPP232914  NATIONAL SECURITY OFFICER PROGRAM FOR THE WESTERN SERVICE AREA (WSA)
#  OPP236479  STK MAINTENANCE AND SUPPORT
#  OPP255730  GUARD II ARMED SECURITY PROTECTIVE OFFICERS FLORIDA BPA CURRENT AND FUTURE DISASTERS
#  OPP205690  DLA MAINTENANCE REPAIR AND OPERATIONS TAILORED LOGISTICS SUPPORT PRIME VENDOR PROGRAM FOR
#  OPP244858  INTELLIGENCE PROGRAM MANAGEMENT SUPPORT
#  OPP251898  EDUCATION SERVICES FOR K12 STUDENTS AT DOVER AFB DE
#  OPP252532  UNARMED GUARD SERVICES AT CAVEN POINT MARINE TERMINAL JERSEY CITY NJ
#  OPP224430  SUPPORT SERVICES FOR OPERATIONS AND MAINTENANCE OF THE NEXTGEN PAVEMENT MATERIALS LABORATO
#  OPP255726  DIPLOMATIC SECURITY HOTEL AND LODGING SPACE IDIQ
#  OPP253010  RIVANNA STATION BASE OPERATIONS
#  OPP209261  INTERMENTS INURNMENTS AND GROUNDS AND FACILITY MAINTENANCE SERVICES FOR THE LOS ANGELES NA
#  OPP217690  GROUNDS MAINTENANCE FOR NORTHWOODS CEMETERY AT RHINELANDER WISCONSIN
#  OPP248858  WATER EMERGENCY AND RAPID RESPONSE SERVICES (WERRS)
#  OPP187900  PRESERVATION OF THE FORCE AND FAMILIES (POTFF)
#  OPP232899  ELECTROMAGNETIC SPECTRUM SERVICES APPLIED ENGINEERING MOBILE SERVICE PROVIDER SUPPORT (EMS
#  OPP255593  TECHNOLOGY TRANSFER AND TRANSITION DIRECTORATE LEVEL SUPPORT (DAFT3)
#  OPP254677  UNITED STATES POSTAL SERVICE OFFICE OF INSPECTOR GENERALS IT MANAGED SERVICE DESK SOLUTION
#  OPP251228  USACE SUPPORT DAM AND LEVEE SAFETY ENGINEERING DESIGN RISK ANALYSIS TECHNICAL REVIEW SAFET
#  OPP160186  MILITARY SEALIFT COMMAND MSC N6 AFLOAT OPERATIONS SUPPORT
#  OPP254082  IDS MAINTENANCE SERVICES FOR FORT HUNTER LIGGETT AND PRFTA CA
#  OPP245452  DAF CIVILIAN WELLNESS
#  OPP254982  RECORDS AND INFORMATION MANAGEMENT ADMINISTRATIVE SERVICES (RIMAS)
#  OPP208961  ENGINE MANAGEMENT AND WAREHOUSE SUPPORT SERVICES FOR NAVSUP FLEET LOGISTICS CENTER JACKSON
#  OPP206987  CENTER OPERATIONS AND MAINTENANCE SERVICES CONTRACT (COMS)
#  OPP241620  SUBSISTENCE PRIME VENDOR SUPPORT FOR SOUTHERN EUROPE AND NAVY SHIPS (OCONUS)(SPV)
#  OPP246303  P180 NAVAL INNOVATION CENTER NAVAL SUPPORT ACTIVITY MONTEREY CA
#  OPP255763  ENGINE MANAGEMENT AND WAREHOUSE SUPPORT SERVICES FOR NAVSUP FLEET LOGISTICS CENTER JACKSON
#  OPP249298  DESIGN BID BUILD FOR THE P440 P441 RECRUIT BARRACKS MCRD PARRIS ISLAND SOUTH CAROLINA
#  OPP225434  AMCOM EXPRESS ON RAMP 2023 TECHNICAL DOMAIN NAICS 541330
#  OPP255798  M1PZ  TORPEDO WEAPONS RETRIEVER TWR OPERATIONS AND MAINTENANCE SERVICES
#  OPP253930  BEDDOWN SITE PREPARATION PROJECT RYGGE NORWAY
#  OPP219683  AUTOMATED INFORMATION SYSTEM DESIGN AND INTEGRATION SERVICES AT FORT LIBERTY NC
#  OPP249498  MATOC FOR SERVICING LOCATIONS IN TEXAS FOR THE 63RD READINESS DIVISION REGION 2 (DB)
#  OPP220831  JONES ACT US WEST COAST TANKER
#  OPP253207  JANITORIAL SERVICES AT AIR STATION SAVANNAH (USCG)
#  OPP241462  MEDICAL SUPPORT SERVICES FOR THE CENTER FOR DOMESTIC PREPAREDNESS
#  OPP204208  PREKINDERGARTEN COMPREHENSIVE CURRICULUM PORTFOLIO AND ASSESSMENT SYSTEM
#  OPP255673  RECOMPETE OF GIS SOFTWARE SOLUTIONS AND DEVELOPMENT SUPPORT SERVICES
#  OPP251473  OEHE GIS SUPPORT SERVICES
#  OPP244990  CONSTRUCTION MANAGEMENT SERVICES II NAVFAC PACIFIC AOR
#  OPP201195  US MISSION PORTUGAL LOCAL GUARD SERVICES
#  OPP251058  ASSET FORFEITURE BRANCH SPECIALIZED PROFESSIONAL SUPPORT
#  OPP200925  M1PZ  TORPEDO WEAPONS RETRIEVER TWR OPERATIONS AND MAINTENANCE SERVICES
#  OPP233024  TEST SUPPORT SERVICES
#  OPP225720  PEST CONTROL SERVICES NSA CRANE AND GLENDORA TEST FACILITY
#  OPP252815  DESIGN BUILD P1678 NATO JFCNF PHASE II INTERIM MODULAR FACILITY NAVAL SUPPORT ACTIVITY NSA
#  OPP231229  SPANGDAHLEM LOCAL DRAYAGE
#  OPP246680  US COAST GUARD BASE MIAMI BEACH GROUNDS MAINTENANCE
#  OPP193802  TEST ENGINEERING AND ANALYSIS SUPPORT SERVICES FOR THE WHITE SANDS MISSILE RANGE (TEAS)
#  OPP243911  AIR FORCE RESERVE INSTRUCTOR SUPPORT SERVICES (AFRISS)
#  OPP255528  DISTRICT COURT GRAND JURY COURT REPORTING SERVICES FOR THE UNITED STATES ATTORNEYS OFFICE
#  OPP220011  USACE 88TH RD NORTH PLAINS PREVENTATIVE AND CORRECTIVE MAINTENANCE WITHIN MINNEAPOLIS REGI
#  OPP211844  BUSINESS FINANCIAL AND ADMINISTRATIVE SUPPORT (BFAS)
#  OPP246941  MEDICAL SUPPORT SERVICES FOR TNARNG
#  OPP254386  VIRTUAL SCENARIO TRAINER INSTALLATION AND TRAINING
#  OPP238578  US ARMY TACOM FIELD SUSTAINMENT SUPPORT SERVICES (FSS)
#  OPP240491  MARINE CORPS TACTICAL SYSTEMS SUPPORT ACTIVITY NETWORK INFRASTRUCTURE SERVICES
#  OPP252873  MAINTENANCE REPAIR AND OPERATIONS TAILORED LOGISTICS SUPPORT PRIME VENDOR PACIFIC REGION (
#  OPP250802  MAINTENANCE REPAIR AND OPERATIONS TAILORED LOGISTICS SUPPORT EUCOM AND AFRICOM AREAS OF RE
#  OPP190664  CIVIL ENGINEERING FACILITY AND EQUIPMENT SUPPORT FOLLOW ON 2025
#  OPP207725  RISK MANAGEMENT SUPPORT SERVICES
#  OPP211341  SURVEY OF INTERNATIONAL AIR TRAVELERS (SIAT)
#  OPP255592  MASTER BPA FOR JANITORIAL AND PROFESSIONAL FLOOR CLEANING SERVICES AT THE ARMED FORCES REC
#  OPP241145  COMPUTER SIMULATION AND CONTROL DATA ANALYSIS CODE 80 (SEAPORT NXG)
#  OPP254269  ZERO TRUST FUNCTIONAL MANAGEMENT OFFICE SUPPORT (ZT FMO)
#  OPP252948  249M IDIQ MATOC FOR ARCHITECT ENGINEER SERVICES OMAHA DISTRICT
#  OPP250846  USACE LEADERSHIP DEVELOPMENT PROGRAM FOR THE PORTLAND DISTRICT
#  OPP243973  TRANSIENT ALERT SERVICES AND AEROSPACE GROUND EQUIPMENT MAINTENANCE FOR PETERSON AFB
#  OPP255506  INFORMATION RECORD MANAGEMENT SERVICES
#  OPP212135  JPM CBRN SENSORS ACQUISITION SUPPORT SERVICES
#  OPP220571  GROUND MAINTENANCE SERVICES AT JEFFERSON BARRACKS NATIONAL CEMETERY
#  OPP245597  GOCO INTELLIGENCE SURVEILLANCE AND RECONNAISSANCE SERVICES (ISR)
#  OPP214140  LAKEHURST AND WEST POINT PREVENTATIVE MAINTENANCE SERVICES
#  OPP240402  DESIGN AND CONSTRUCTION SERVICES FOR AN MEGA MACC FOR FACILITIES WITHIN THE NAVAC WASHINGT
#  OPP242787  FY 25 NEW HIRES WORKSTATION SURGE SUPPORT
#  OPP247219  AIR FORCE RESEARCH AEROSPACE SYSTEMS DIRECTORATE LABORATORY ELECTRICAL EMERGENCY RESPONSE
#  OPP249939  THREAT MITIGATION AND MONITORING
#  OPP216936  L39 QUALITATIVE EVALUATION
#  OPP253023  INTEGRATE AND FACILITATE A SOFTWARE DEVELOPMENT ENVIRONMENT AT FUTURE KC 46 SOFTWARE INTEG
#  OPP251186  TELERADIOLOGY SERVICES BILLINGS AREA
#  OPP212611  GLOBAL PROTECTIVE SERVICES (GPS)
#  OPP240408  LOGISTICS SERVICES AND CONTINUOUS MONITORING PROGRAM CMP CONTRACT
#  OPP255671  AUDIOVISUAL ENTERPRISE SERVICES BPA
#  OPP214452  CENTER MAINTENANCE OPERATIONS AND ENGINEERING II (CMOE II)
#  OPP205191  SECURITY SUPPORT SERVICES FOR JIATF SOUTH COMMAND
#  OPP252542  NOGALES INTERNATIONAL WASTEWATER TREATMENT PLANT MULTIPLE AWARD INDEFINITE DELIVERY INDEFI
#  OPP251697  RUGID SCADA CENTRAL AND REMOTE MONITORING EQUIPMENT AND SOFTWARE SYSTEMS
#  OPP250464  WORKPLACE DOMESTIC VIOLENCE PROGRAM VIOLENCE RISK OR BEHAVIORAL THREAT ASSESSMENT CONSULTA
#  OPP224731  CORPORATE STRATEGY DIVISIONS ROBOTIC PROCESS AUTOMATION DEVELOPMENT AND TRAINING SUPPORT
#  OPP205552  GROUNDS MAINTENANCE SERVICES FOR ANNAPOLIS NATIONAL CEMETERY AND LOUDON PARK NATIONAL CEME
#  OPP214085  NASA RESEARCH AND EDUCATION SUPPORT SERVICES III (NRESS III)
#  OPP236178  F22 DORMITORY LANGLEY AFB
#  OPP234339  GROUNDS MAINTENANCE SERVICES FOR BAY PINES NATIONAL CEMETERY
#  OPP235439  PMR 51 SUPPORT SERVICES (SEAPORT NXG)
#  OPP250297  ALS CONTINUING EDUCATION CLASSES
#  OPP249879  FARGO NATIONAL CEMETERY GROUNDS MAINTENANCE AND BURIAL OPERATIONS
#  OPP233011  DBB SUSTAINMENT RESTORATION MODERNIZATION FOR VARIOUS LOCATIONS IN ALASKA
#  OPP201715  LOCAL GUARD SERVICES US MISSION CANADA
#  OPP255580  VISUAL INFORMATION SUPPORT SERVICES (VISS)
#  OPP207923  SPECIAL PROJECTS AND ELECTRONIC SYSTEMS ENGINEERING SUPPORT FOR ELECTRONIC SURVEILLANCE SY
#  OPP239072  LOCAL GUARD SERVICES BANJUL GAMBIA
#  OPP247695  MICROSOFT UNIFIED SUPPORT AGREEMENT AND INDUSTRY SOLUTIONS DELIVERY (MUSA & ISD)
#  OPP225847  DBB REPLACE SPILLWAY BRIDGE FORT GIBSON LAKE OK
#  OPP251115  FORENSIC PSYCHIATRIST FOR THE CRITICAL INCIDENT RESPONSE GROUP (CIRG)
#  OPP253037  INFORMATION TECHNOLOGY ARTIFICIAL INTELLIGENCE MACHINE LEARNING PROGRAMMATIC SUPPORT SERVI
#  OPP231330  INTELLIGENCE SYSTEMS HARDWARE ENGINEERING AND LOGISTICS SERVICES IN SUPPORT OF IRREGULAR W
#  OPP249102  CONSTRUCTION PROJECT FOR BUILDING ANDOR HEAVY NON BUILDING RESIDENTIAL REQUIREMENTS FOR P9
#  OPP255774  NY National Guard Recruiting and Retention Battalion Support Services
#  OPP255377  OC UAS RESOURCE FLIGHT SERVICES
#  OPP237149  PROFESSIONAL SUPPORT SERVICES PSS IN SUPPORT OF PMS 460 (SEAPORT NXG)
#  OPP219492  NATIONAL SECURITY SPACE INSTITUTE INSTRUCTOR AND SUPPORT SERVICES (NSSI)
#  OPP210414  FULL SCALE VEHICLE FRONTAL RIGID BARRIER IMPACT TESTING AND SIDE AIR BAG OUT OF POSITION T
#  OPP254582  GERMANY AIR MAIL TERMINAL IV (GAMT IV)
#  OPP230891  USCG RESCUE 21 WESTERN RIVERS VHF COMMUNICATION SYSTEM ORGANIZATIONAL MAINTENANCE
#  OPP236278  PROTECTIVE SECURITY OFFICER SERVICES FOR THE STATE OF KENTUCKY
#  OPP232410  ARCHITECT ENGINEER SERVICES FOR GEOTECHNICAL ENVIRONMENTAL AND SURVEYING SERVICES MID ATLA
#  OPP191018  REPAIRS TO DIKE 7 ALONG FOLSOM DAM IN CALIFORNIA
#  OPP244952  IDIQ MAC FOR OUTSOURCING WORK FROM CHIEF OF NAVAL OPERATIONS CNO AVAILABILITIES ON FAST AT
#  OPP245956  GROUND BASED ELECTRO OPTICAL DEEP SPACE SURVEILLANCE (GEODSS)
#  OPP210110  AEROSPACE GROUND EQUIPMENT SUPPORT FUELS MANAGEMENT AND TRANSIENT ALERT
#  OPP249486  FUTURE NASA HEADQUARTERS
#  OPP255664  DATA INTEGRATION RESOURCE MANAGEMENT ANALYST SERVICES
#  OPP245947  ICE WEST COAST MULTI STATE
#  OPP186813  CONTRACTOR LOGISTIC SUPPORT SERVICES FOR C12 AIRCRAFT FLEET (C-12 CLS)
#  OPP241242  PEO SDA INTEGRATED SURVEY PROGRAM MODERNIZATION (ISP)
#  OPP224368  SOFTWARE SUPPORT EARTHQUAKE MONITORING AND DATA PRODUCT DISTRIBUTION
#  OPP230693  IT SUPPORT SERVICES FOR NAVAL SURFACE WARFARE CENTER INDIAN HEAD EXPLOSIVE ORDNANCE DISPOS
#  OPP255728  WORLDWIDE HVAC AND BAS SUPPORT SERVICES
#  OPP245311  CODE 85 PROPULSION TEST FACILITY PTF OPERATIONS AND MAINTENANCE SUPPORT SERVICES
#  OPP209769  UNIFORMED SECURITY SERVICES FOR THE CLEVELAND VA MEDICAL CENTER FISHER HOUSE LOCATION
#  OPP225924  GLENN LOGISTICS AND METROLOGY (GLAM)
#  OPP252827  NASA JOHN F KENNEDY SPACE CENTER SMALL TASK ORDER CONSTRUCTION CONTRACT
#  OPP230745  USACE AEC IDIQ MATOC TWO PHASE DB AND CONSTRUCTION FOR MEDICAL RESEARCH DEVELOPMENT COMMAN
#  OPP255532  EMERGENCY NOTIFICATION AND ACCOUNTABILITY SYSTEM SOFTWARE AS A SERVICE AND MAINTENANCE AND
#  OPP204266  AEC ARCHITECT ENGINEER AE IDIQ CONTRACT FOR THE STATES COVERED BY EPA REGIONS 5 THROUGH 10
#  OPP235005  INDEPENDENT PROGRAM ASSESSMENTS (IPA)
#  OPP255543  CYBER PLATFORMS AND SYSTEMS PROGRAM MANAGEMENT ADVISORY AND ASSISTANCE SERVICES
#  OPP250391  DIGITAL IMAGING NETWORK PICTURE ARCHIVE AND COMMUNICATION SYSTEM WORKFLOW ANALYSIS AND TRA
#  OPP210564  LYSTER ARMY HEALTH CLINIC SECURITY SYSTEM AT FORT NOVOSEL ALABAMA
#  OPP216664  LONG TERM PAVEMENT PERFORMANCE TECHNICAL SUPPORT SERVICES CONTRACT (LTPP)
#  OPP255710  DAF PEO C3BM STRATEGIC LEADERSHIP DESIGN
#  OPP249426  ROYAL AIR FORCE BLENHEIM CRESCENT SECURITY (RAF)
#  OPP245636  USAFA GROUNDS MAINTENANCE
#  OPP225012  ENTERPRISE COLLECTION PLANNER PRIME INTEGRATION SUPPORT AND SERVICES (ECP)
#  OPP239979  DSCA IRREGULAR WARFARE CENTER SUPPORT SERVICES
#  OPP145624  HUMAN HEALTH AND PERFORMANCE CONTRACT 2 (HHPC2)
#  OPP252925  NATIONAL INSTITUTE ON AGING ANIMAL CARE SUPPORT SERVICES
#  OPP254636  GROUND MAINTENANCE SERVICES  AT MOROVIS NATIONAL CEMETERY
#  OPP252782  WASHINGTON HEADQUARTERS SERVICES COMMERCIAL SOLUTIONS OPENING (CSO)
#  OPP242186  MILLION VETERAN PROGRAM PRINTING AND MAILING SUPPORT SERVICES (MVP)
#  OPP255356  RX PHARMACEUTICAL PRESCRIPTION DATA
#  OPP238565  USING RODENT BEHAVIORAL MODELS TO IDENTIFY SUBSTANCE USE DISORDER PHARMACOTHERAPIES
#  OPP219361  NGS SCIENTIFIC AND PROFESSIONAL TECHNICAL SUPPORT SERVICES
#  OPP232011  NGA INTEGRATED CAMPUS SUPPORT (NICS)
#  OPP250739  USAID VIETNAM HIGHER EDUCATION POLICY SUPPORT (HEDS)
#  OPP247265  MEDICAL SERVICES COLUMBIA BASIN JOB CORPS CENTER
#  OPP255584  OPERATION  MAINTENANCE OF THE SOUTH BAY WAST WATER TREATMENT PLANT
#  OPP235608  VIDEO SURVEILLANCE SYSTEM AND INTRUSION DETECTION SYSTEM MAINTENANCE AND REPAIR SERVICES F
#  OPP246026  SUPPORT FOR IRS INTEREST PROGRAM
#  OPP249615  FBI REDSTONE JOB ORDER CONTRACT
#  OPP251211  ADMINISTRATIVE SCIENTIFIC AND TECHNICAL SUPPORT SERVICES OF THE CHEMICAL BIOLOGICAL RADIOL
#  OPP241570  HERMITS PEAK CALF CANYON CLAIMS REVIEW TECHNICAL SUPPORT
#  OPP252828  FEDRAMP MAIL TRACKING SYSTEM
#  OPP246832  HEIMDALL BAA
#  OPP237910  AEC DB AK NATIONAL GUARD READINESS CENTER IN ANCHORAGE AK (JBR032)
#  OPP198782  AJW INTEGRATED SUPPORT SERVICES (AISS)
#  OPP253933  J EDGAR HOOVER BUILDING CAFETERIA RENOVATION
#  OPP208152  TAAS IDIQ FOR IA DWP (DWP)
#  OPP252562  INTELLIGENCE ANALYSTS SUPPORT SERVICES
#  OPP233549  INFORMATION MONITORING AND PROTECTION SERVICES (IMPS)
#  OPP242989  WORLDWIDE OPERATIONS MAINTENANCE AND TECHNICAL SUPPORT JALBTCX
#  OPP224315  FULL FOOD SERVICES AT US COAST GUARD SECTOR SOUTH EAST NEW ENGLAND SENE WOODS HOLE MA
#  OPP250581  FOREST SERVICE JOB CORPS OUTREACH AND ADMISSIONS AND CAREER TRANSITION SERVICES FOR THE CH
#  OPP228307  ENTERPRISE ASSET MANAGEMENT SYSTEM SOFTWARE APPLICATION PROCUREMENT INSTALLATION AND CUSTO
#  OPP250591  PHYSICAL SECURITY FOR FORT SAINT VRAIN IN COLORADO
#  OPP235994  DBB LIGHTERAGE AND SMALL CRAFT FACILITY MCSF BLOUNT ISLAND JACKSONVILLE FLORIDA
#  OPP108089  EVOLVE IDIQ
#  OPP236026  ENVIRONMENTAL FENCE TO FENCE FOR JOINT BASE ELMENDORF RICHARDSON EIELSON AIR FORCE BASE CL
#  OPP204197  GLOBAL INFRASTRUCTURE AND DEVELOPMENT ACQUISITION 2 (GLINDA 2.0)
#  OPP251967  CONSOLIDATED LAUNDRY SERVICES
#  OPP209671  CONTRACTOR LOGISTICS SUPPORT FOR MULTIPLE AIR FORCE TERRESTRIAL BASED AIR SURVEILLANCE SEN
#  OPP210429  PSYCHOLOGICAL ASSESSMENT SUPPORT SERVICES
#  OPP253046  AN APG81 RADAR OPERATIONAL FLIGHT PROGRAM AND THE AN AAQ37 DISTRIBUTED APERTURE SYSTEM (OF
#  OPP208287  SUPPLEMENTAL DENTAL BENEFITS
#  OPP213910  USCG ENTERPRISE ACQUISITION SUPPORT SERVICES
#  OPP242446  FY26 DUCKABUSH ESTUARY RESTORATION IN BRINNON  WA
#  OPP217703  DATA AND ANALYTICAL SERVICES
#  OPP248857  TECHNICAL ASSESSMENT RESPONSE TEAM (TART)
#  OPP254559  STRATEGIC TACTICAL EQUIPMENT AND LOGISTICS (STEAL)
#  OPP233864  DBB POWER GENERATION AND MICROGRID PROJECT AT ANNISTON ARMY DEPOT AL
#  OPP189822  USACE AEC VERTICAL CONSTRUCTION  SERVICE DISABLED VETERAN OWNED SOUTHWESTERN REGION
#  OPP255126  H CARL MOULTRIE COURTHOUSE COURTROOM 120 MODERNIZATION (HCMC)
#  OPP255638  PM MOUNTED ARMORED VEHICLE SYSTEMS LOGISTIC FIELD SERVICE SUPPORT SYSTEM TECHNICAL SUPPORT
#  OPP243206  CRIMINAL INVESTIGATIONS CI CONTINUOUS DIAGNOSTICS AND MITIGATION CDM SUPPORT SERVICES (CI
#  OPP229088  AUTOIMMUNE DISEASES STATISTICAL  CLINICAL COORDINATING CENTER
#  OPP215069  TRIAL COURTROOM SUPPORT SERVICES
#  OPP239625  CBP HRM MEDICAL SUPPORT SERVICES PRE AND POST EMPLOYMENT
#  OPP209521  COMMUNITY CARE NETWORK NEXT GENERATION MEDICAL NETWORK EAST (CCN NEXT GEN)
#  OPP255527  LANDSCAPING AND GROUNDS MAINTENANCE SERVICES
#  OPP254394  ARMY CONTRACTING COMMAND ANNISTON ARMY DEPOT ACCHDA ORGANIC INDUSTRIAL BASE OIB MODERNIZAT
#  OPP255668  ENTERPRISE COLLECTION PLANNER PRIME INTEGRATOR DEVELOPER
#  OPP177988  COLLABORATIVE COMBAT AIRCRAFT PROGRAM INCREMENT 1 (CCA)
#  OPP254604  VOPS OPERATIONS ANALYSIS AND COST ESTIMATING (SEAPORT NXG)
#  OPP250490  DIPLOMATIC POUCH AND MAIL SERVICES
#  OPP167320  GLOBAL MODELING AND ASSIMILATION SUPPORT (GLOMAS)
#  OPP231689  TINKER AIR FORCE BASE OPERATIONS SUPPORT SERVICE (TAFB BOSS)
#  OPP246786  ENGINEERING AND CONSTRUCTION MANAGEMENT SERVICES FOR VARIOUS CIVIL WORKS ENVIRONMENTAL DEP
#  OPP254190  CONSOLIDATED RESOURCES CENTER SUPPORT (CRC)
#  OPP211922  HHS OIS CYBERSECURITY AND INFORMATION TECHNOLOGY SERVICES
#  OPP253494  NATIONAL DEFENSE SCIENCE AND ENGINEERING GRADUATE FELLOWSHIP PROGRAM (NDSEG)
#  OPP219530  INSTRUMENTATION RANGE SUPPORT PROGRAM IV (IRSP IV)
#  OPP251646  INTERCONNECTION POINT ICP COLOCATIONS
#  OPP179844  RIO PUERTO NUEVO FLOOD CONTROL PROJECT SUPPLEMENTAL CONTRACT 3 CHANNEL BOTTOM AND WALL IMP
#  OPP232547  GROUND BASED STRATEGIC DETERRENT INTEGRATED TRAINING FACILITY FE WARREN AFB WYOMING (GBSD)
#  OPP255801  SUSTAINMENT CENTER OF EXCELLENCE INSTRUCTOR TRAINING SUPPORT AND DEVELOPMENT (SCOE)(ITSD)
#  OPP141503  ICBM DEVELOPMENT OPERATIONS AND SUSTAINMENT (IDOS)
#  OPP186832  SUSTAINMENT CENTER OF EXCELLENCE INSTRUCTOR TRAINING SUPPORT AND DEVELOPMENT (SCOE)(ITSD)
#  OPP234944  CRIMINAL JUSTICE INFORMATION SERVICES DIVISION CAFETERIA SERVICES
#  OPP253841  USAFA Admissions Strategic Outreach Services
#  OPP213928  CLINICAL CENTRAL LABORATORY SERVICES
#  OPP201718  INDUSTRIAL PSYCHOLOGIST
#  OPP230423  ARC HEATED TEST FACILITY EXHAUST SYSTEM
#  OPP238065  TSB FLEXIBLE AGILE DEVELOPMENT SERVICES (TFADS)
#  OPP222926  CONSTRUCTION SUPPORT PROFESSIONAL SERVICES IDIQ
#  OPP231888  CLOUD ONE NEXT ARCHITECTURE AND COMMON SHARED SERVICES (C1N ACSS)
#  OPP224407  RESOURCE FOR THE COLLECTION OF HUMAN TISSUES CELLS BIOFLUIDS AND EPIDEMIOLOGIC PROFILES FR
#  OPP110290  MANAGEMENT AND OPERATION OF THE SAVANNAH RIVER SITE (SRS M&O)
#  OPP252085  MULTIPLE AWARD AEP IDIQ SERVICES CONTRACTS
#  OPP224377  ICE HSI FORENSIC LABORATORY LIBRARY INFORMATION MANAGEMENT SYSTEM (HSI-FL IT LIMS)
#  OPP243438  PRODUCTION OF AIRCREW TRAINING DEVICES AND FULL DEVELOPING OF RVS 2 UPDATE FOR BOOM OPERAT
#  OPP255776  HAZARDOUS WASTE TECHNICIAN SUPPORT
#  OPP240881  RAPID ADVANCED CAPABILITY TRANSITION MULTIPLE AUTHORITY ANNOUNCEMENT (REACT)(MAA)
#  OPP173346  AIRCRAFT SYSTEMS AND SPACEFLIGHT ENGINEERING SUPPORT SERVICES (ASSESS)
#  OPP236165  DBB JOINT INTEGRATED TEST AND TRAINING CENTER JBER ALASKA (JBE088)
#  OPP186896  OFFICE OF CORPORATE COMMUNICATIONS SUPPORT SERVICES
#  OPP255639  DHS CBP COMMERCIAL SOLUTIONS OPENING TRADE SOLUTIONS PILOT (CSO TSP)
#  OPP255691  OFFICE OF CORPORATE COMMUNICATIONS SUPPORT SERVICES
#  OPP160222  MANAGEMENT AND OPERATION OF THE NAVAL NUCLEAR LABORATORY AND NAVAL NUCLEAR PROPULSION PROG
#  OPP238333  ENTERPRISE ACQUISITION SUPPORT SERVICES AND ACQUISITION SUPPORT SERVICES
#  OPP178774  ORR NATIONAL CALL CENTER AND SEXUAL ABUSE HOTLINE
#  OPP172214  STREAMLINED TECHNOLOGY ACQUISITION RESOURCES FOR SERVICES III (STARS III)
#  OPP230948  CUSTODIAL SERVICES FOR MOUNTAIN HOME AFB
#  OPP246846  EX VIRENTIA PROGRAM PHASE 0 (EXVI)
#  OPP229924  EGLIN AFB INTEGRATED SOLID WASTE MANAGEMENT
#  OPP201788  SOLUTIONS FOR ENTERPRISEWIDE PROCUREMENT VI (SEWP VI)
#  OPP194453  ELECTRONIC FAA ACCELERATED AND SIMPLIFIED MASTER ORDERING AGREEMENT OPEN SEASON 7 (EFAST M
#  OPP229755  OASIS PLUS MULTI AGENCY CONTRACT SERVICE DISABLED VETERAN OWNED SMALL BUSINESS (OASIS+  SD
#  OPP229756  OASIS PLUS MULTI AGENCY CONTRACT SMALL BUSINESS (OASIS+ SB)

# %%
"""
GovWin Personnel Security Opportunities API Tool
Retrieves opportunities matching "personnel security" from the last 24 hours
with comprehensive data extraction and error handling.
"""
import os
import sys
import time
import json
import dotenv
import requests
from datetime import datetime, timedelta
from typing import Dict, List, Optional, Any

dotenv.load_dotenv()

class GovWinAPI:
    def __init__(self):
        self.base_url = "https://services.govwin.com"
        self.token_url = f"{self.base_url}/neo-ws/oauth/token"
        self.search_url = f"{self.base_url}/neo-ws/opportunities"
        self.access_token = None
        self.token_expiry = None
        
    def get_access_token(self) -> str:
        """Get OAuth2 access token (valid for 12 hours)."""
        if self.access_token and self.token_expiry and time.time() < self.token_expiry:
            return self.access_token
            
        try:
            response = requests.post(
                self.token_url,
                data={
                    "client_id": os.getenv("GOVWIN_CLIENT_ID"),
                    "client_secret": os.getenv("GOVWIN_CLIENT_SECRET"),
                    "grant_type": "password",
                    "username": os.getenv("GOVWIN_USERNAME"),
                    "password": os.getenv("GOVWIN_PASSWORD"),
                    "scope": "read",
                },
                headers={"Content-Type": "application/x-www-form-urlencoded"},
                timeout=20,
            )
            
            if response.status_code != 200:
                raise Exception(f"Auth failed {response.status_code}: {response.text}")
                
            token_data = response.json()
            self.access_token = token_data["access_token"]
            self.token_expiry = time.time() + token_data["expires_in"] - 300  # 5 min buffer
            
            expires_str = time.strftime("%Y-%m-%d %H:%M:%S", 
                                      time.localtime(self.token_expiry))
            print(f"✓ Token obtained - expires {expires_str}")
            
            return self.access_token
            
        except Exception as e:
            print(f"❌ Authentication failed: {e}")
            sys.exit(1)
    
    def safe_get(self, data: Dict, path: str, default: Any = None) -> Any:
        """Safely get nested dictionary values."""
        try:
            keys = path.split('.')
            result = data
            for key in keys:
                if isinstance(result, dict) and key in result:
                    result = result[key]
                else:
                    return default
            return result
        except:
            return default
    
    def extract_opportunity_data(self, opp: Dict) -> Dict:
        """Extract all relevant data from an opportunity, handling missing fields gracefully."""
        extracted = {
            # Basic Information
            "opportunity_id": self.safe_get(opp, "id"),
            "iq_opp_id": self.safe_get(opp, "iqOppId"),
            "title": self.safe_get(opp, "title"),
            "status": self.safe_get(opp, "status"),
            "type": self.safe_get(opp, "type"),
            "internal_status": self.safe_get(opp, "internalStatus"),
            
            # Dates
            "created_date": self.safe_get(opp, "createdDate"),
            "update_date": self.safe_get(opp, "updateDate"),
            "solicitation_date": self.safe_get(opp, "solicitationDate.value"),
            "response_date": self.safe_get(opp, "responseDate"),
            "award_date": self.safe_get(opp, "awardDate"),
            "termination_date": self.safe_get(opp, "terminationDateTx"),
            
            # Solicitation Information
            "solicitation_number": self.safe_get(opp, "solicitationNumber"),
            "source_url": self.safe_get(opp, "sourceURL"),
            
            # Financial Information
            "opp_value": self.safe_get(opp, "oppValue"),
            "opp_value_canada": self.safe_get(opp, "oppValueCanada"),
            "plan_price_tx": self.safe_get(opp, "planPriceTx"),
            "plan_price_canadian": self.safe_get(opp, "planPriceCanadian"),
            "fed_prime_obligation_amt": self.safe_get(opp, "fedPrimeObligationAmt"),
            "revenue": self.safe_get(opp, "revenue"),
            
            # Government Entity
            "gov_entity_id": self.safe_get(opp, "govEntity.id"),
            "gov_entity_title": self.safe_get(opp, "govEntity.title"),
            "gov_type": self.safe_get(opp, "govType"),
            
            # Classification and Requirements
            "primary_naics_id": self.safe_get(opp, "primaryNAICS.id"),
            "primary_naics_title": self.safe_get(opp, "primaryNAICS.title"),
            "primary_naics_size_standard": self.safe_get(opp, "primaryNAICS.sizeStandard"),
            "classification_code_desc": self.safe_get(opp, "classificationCodeDesc"),
            "primary_requirement": self.safe_get(opp, "primaryRequirement"),
            "procurement": self.safe_get(opp, "procurement"),
            
            # Competition and Contract Information
            "competition_types": [],
            "contract_types": [],
            "additional_naics": [],
            
            # Location and Performance
            "country": self.safe_get(opp, "country"),
            "city": self.safe_get(opp, "city"),
            "zip": self.safe_get(opp, "zip"),
            
            # Description and Duration
            "description": self.safe_get(opp, "description"),
            "duration": self.safe_get(opp, "duration"),
            
            # Security and Business Requirements
            "capabilities": self.safe_get(opp, "capabilities"),
            "cage_code": self.safe_get(opp, "cageCode"),
            "cmmc_requirements": self.safe_get(opp, "cmmcRequirements"),
            "socio_economic_status": self.safe_get(opp, "socioEconomicStatus"),
            "small_bus_naics": self.safe_get(opp, "smallBusNaics"),
            "org_certification": self.safe_get(opp, "orgCertification"),
            "org_facility_clearance": self.safe_get(opp, "orgFacilityClearance"),
            "org_staff_clearance": self.safe_get(opp, "orgStaffClearance"),
            
            # Estimates and Flags
            "is_deltek_estimate": self.safe_get(opp, "isDeltekEstimate"),
            "priority": self.safe_get(opp, "priority"),
            
            # Award Information
            "type_of_award": self.safe_get(opp, "typeOfAward"),
            "exclusion_type": self.safe_get(opp, "exclusionTypeTx"),
            
            # Partner Information
            "partner_response_date": self.safe_get(opp, "partnerResponseDate"),
            
            # Links
            "web_href": self.safe_get(opp, "links.webHref.href"),
        }
        
        # Extract competition types
        comp_types = self.safe_get(opp, "competitionTypes", [])
        if comp_types:
            extracted["competition_types"] = [
                {
                    "id": self.safe_get(comp, "id"),
                    "title": self.safe_get(comp, "title")
                }
                for comp in comp_types
            ]
        
        # Extract contract types
        contract_types = self.safe_get(opp, "contractTypes", [])
        if contract_types:
            extracted["contract_types"] = [
                {
                    "id": self.safe_get(cont, "id"),
                    "title": self.safe_get(cont, "title")
                }
                for cont in contract_types
            ]
        
        # Extract additional NAICS
        add_naics = self.safe_get(opp, "additionalNaics", [])
        if add_naics:
            extracted["additional_naics"] = [
                {
                    "id": self.safe_get(naics, "id"),
                    "title": self.safe_get(naics, "title"),
                    "size_standard": self.safe_get(naics, "sizeStandard")
                }
                for naics in add_naics
            ]
        
        return extracted
    
    def search_personnel_security_opportunities(self, 
                                              last_hours: int = 24,
                                              max_results: int = 100,
                                              include_naics: List[str] = None,
                                              include_psc: List[str] = None) -> Dict:
        """
        Search for personnel security opportunities from the last N hours.
        
        Args:
            last_hours: Number of hours to look back (default: 24)
            max_results: Maximum results per page (default: 100, max: 100)
            include_naics: Optional list of NAICS codes to include
            include_psc: Optional list of PSC codes to include
        """
        token = self.get_access_token()
        
        # Build search parameters
        params = {
            "q": '"personnel security"',  # Exact phrase search
            "oppSelectionDateFrom": f"-{last_hours}H",  # Relative date format
            "oppCategory": 2,  # New and Update
            "max": min(max_results, 100),  # API limit is 100
            "offset": 0,
        }
        
        # Add optional NAICS codes
        if include_naics:
            params["naics"] = ",".join(include_naics)
        
        # Add optional PSC codes  
        if include_psc:
            params["classificationCodes"] = ",".join(include_psc)
        
        try:
            response = requests.get(
                self.search_url,
                headers={"Authorization": f"Bearer {token}"},
                params=params,
                timeout=30,
            )
            
            if response.status_code != 200:
                raise Exception(f"Search failed {response.status_code}: {response.text}")
            
            data = response.json()
            total_count = self.safe_get(data, "meta.paging.totalCount", 0)
            
            print(f"✓ Found {total_count} personnel security opportunities")
            
            # Extract detailed data from each opportunity
            opportunities = []
            for opp in data.get("opportunities", []):
                extracted_opp = self.extract_opportunity_data(opp)
                opportunities.append(extracted_opp)
            
            return {
                "search_metadata": {
                    "search_time": datetime.now().isoformat(),
                    "total_count": total_count,
                    "returned_count": len(opportunities),
                    "search_parameters": params,
                    "hours_back": last_hours
                },
                "opportunities": opportunities
            }
            
        except Exception as e:
            print(f"❌ Search failed: {e}")
            return {
                "search_metadata": {
                    "search_time": datetime.now().isoformat(),
                    "error": str(e),
                    "search_parameters": params
                },
                "opportunities": []
            }
    
    def get_all_recent_opportunities(self, last_hours: int = 24) -> List[Dict]:
        """
        Get all personnel security opportunities from the last N hours,
        handling pagination if necessary.
        """
        all_opportunities = []
        offset = 0
        max_per_page = 100
        
        while True:
            token = self.get_access_token()
            
            params = {
                "q": '"personnel security"',
                "oppSelectionDateFrom": f"-{last_hours}H",
                "oppCategory": 2,
                "max": max_per_page,
                "offset": offset,
            }
            
            try:
                response = requests.get(
                    self.search_url,
                    headers={"Authorization": f"Bearer {token}"},
                    params=params,
                    timeout=30,
                )
                
                if response.status_code != 200:
                    print(f"❌ Pagination request failed: {response.status_code}")
                    break
                
                data = response.json()
                opportunities = data.get("opportunities", [])
                
                if not opportunities:
                    break
                
                # Extract data from this page
                for opp in opportunities:
                    extracted_opp = self.extract_opportunity_data(opp)
                    all_opportunities.append(extracted_opp)
                
                # Check if we got all results
                total_count = self.safe_get(data, "meta.paging.totalCount", 0)
                if len(all_opportunities) >= total_count:
                    break
                    
                offset += max_per_page
                print(f"📄 Retrieved {len(all_opportunities)}/{total_count} opportunities...")
                
                # Add a small delay to respect rate limits
                time.sleep(0.1)
                
            except Exception as e:
                print(f"❌ Pagination error: {e}")
                break
        
        return all_opportunities

def main():
    """Main execution function for testing."""
    api = GovWinAPI()
    
    print("🔍 Searching for personnel security opportunities from last 24 hours...")
    
    # Get opportunities with common NAICS codes for personnel security
    personnel_security_naics = [
        "541611",  # Administrative Management and General Management Consulting Services
        "561611",  # Investigation, Guard, and Armored Car Services
        "541214",  # Payroll Services
    ]
    
    personnel_security_psc = [
        "R408",  # Support- Professional: Program Management/Support Services
        "R703",  # Support- Professional: Other Safety and Security Services
    ]
    
    result = api.search_personnel_security_opportunities(
        last_hours=24,
        max_results=100,
        # include_naics=personnel_security_naics,
        # include_psc=personnel_security_psc
    )
    
    # Print summary
    print(f"\n📊 Search Summary:")
    print(f"   Total opportunities found: {result['search_metadata'].get('total_count', 0)}")
    print(f"   Opportunities retrieved: {result['search_metadata'].get('returned_count', 0)}")
    
    # Print first few opportunities with key details
    if result["opportunities"]:
        print(f"\n📋 Sample Opportunities:")
        for i, opp in enumerate(result["opportunities"][:5], 1):
            print(f"\n   {i}. {opp.get('title', 'No Title')}")
            print(f"      ID: {opp.get('opportunity_id', 'N/A')}")
            print(f"      Status: {opp.get('status', 'N/A')}")
            print(f"      Value: ${opp.get('opp_value', 'N/A')}")
            print(f"      Gov Entity: {opp.get('gov_entity_title', 'N/A')}")
            print(f"      Solicitation #: {opp.get('solicitation_number', 'N/A')}")
            if opp.get('solicitation_date'):
                print(f"      Solicitation Date: {opp.get('solicitation_date', 'N/A')}")
            if opp.get('response_date'):
                print(f"      Response Date: {opp.get('response_date', 'N/A')}")
    
    # Save to JSON file with timestamp
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    filename = f"personnel_security_opportunities_{timestamp}.json"
    
    with open(filename, 'w', encoding='utf-8') as f:
        json.dump(result, f, indent=2, ensure_ascii=False, default=str)
    
    print(f"\n💾 Results saved to: {filename}")
    
    return result

if __name__ == "__main__":
    # Example usage for serverless function
    result = main()
# Out:
# 🔍 Searching for personnel security opportunities from last 24 hours...
# ✓ Token obtained - expires 2025-06-12 02:55:53
# ✓ Found 7 personnel security opportunities
#
# 📊 Search Summary:
#    Total opportunities found: 7
#    Opportunities retrieved: 7
#
# 📋 Sample Opportunities:
#
#    1. FIELD BACKGROUND INVESTIGATIVE SERVICES
#       ID: OPP255515
#       Status: Post-RFP
#       Value: $0
#       Gov Entity: OFFICE OF PROFESSIONAL RESPONSIBILITY AND SECURITY OPERATIONS
#       Solicitation #: 15A00025R00000040
#       Solicitation Date: 2025-06-11T00:00:00.000
#
#    2. SECURITY PROCESSING SUPPORT SERVICES (SPSS)
#       ID: OPP248848
#       Status: Pre-RFP
#       Value: $0
#       Gov Entity: ASST SECRETARY FOR ADMINISTRATION
#       Solicitation #: 75P00125R00002
#       Solicitation Date: 2025-09-30T00:00:00.000
#
#    3. ICE OFFICE OF PROFESSIONAL RESPONSIBILITY TECHNOLOGY SOLUTIONS
#       ID: OPP245230
#       Status: Pre-RFP
#       Value: $0
#       Gov Entity: IMMIGRATION AND CUSTOMS ENFORCEMENT
#       Solicitation #:
#       Solicitation Date: 2025-09-11T00:00:00.000
#
#    4. DOMAIN LOGISTICS SUPPORT FOR THE CENTER FOR EXPLOSIVE ORDNANCE DISPOSAL AND DIVING AT NAVAL SUPPORT ACTIVITY NSA PANAMA CITY FL
#       ID: OPP247490
#       Status: Pre-RFP
#       Value: $0
#       Gov Entity: FLEET LOGISTICS CENTER JACKSONVILLE
#       Solicitation #: N6883625R0002
#       Solicitation Date: 2025-08-29T00:00:00.000
#
#    5. ELECTROMAGNETIC SPECTRUM ENGINEERING ANALYSIS AND SERVICES (EMS EAS)
#       ID: OPP243743
#       Status: Pre-RFP
#       Value: $50000
#       Gov Entity: DEFENSE SPECTRUM ORGANIZATION / JOINT SPECTRUM CENTER
#       Solicitation #: 632469687
#       Solicitation Date: 2025-09-23T00:00:00.000
#
# 💾 Results saved to: personnel_security_opportunities_20250611_155834.json

# %%
"""
GovWin Personnel Security Opportunities API Tool
Retrieves opportunities matching "personnel security" from the last 24 hours
with comprehensive data extraction and error handling.
"""
import os
import sys
import time
import json
import dotenv
import requests
from datetime import datetime, timedelta
from typing import Dict, List, Optional, Any

dotenv.load_dotenv()

class GovWinAPI:
    def __init__(self):
        self.base_url = "https://services.govwin.com"
        self.token_url = f"{self.base_url}/neo-ws/oauth/token"
        self.search_url = f"{self.base_url}/neo-ws/opportunities"
        self.access_token = None
        self.token_expiry = None
        
    def get_access_token(self) -> str:
        """Get OAuth2 access token (valid for 12 hours)."""
        if self.access_token and self.token_expiry and time.time() < self.token_expiry:
            return self.access_token
            
        try:
            response = requests.post(
                self.token_url,
                data={
                    "client_id": os.getenv("GOVWIN_CLIENT_ID"),
                    "client_secret": os.getenv("GOVWIN_CLIENT_SECRET"),
                    "grant_type": "password",
                    "username": os.getenv("GOVWIN_USERNAME"),
                    "password": os.getenv("GOVWIN_PASSWORD"),
                    "scope": "read",
                },
                headers={"Content-Type": "application/x-www-form-urlencoded"},
                timeout=20,
            )
            
            if response.status_code != 200:
                raise Exception(f"Auth failed {response.status_code}: {response.text}")
                
            token_data = response.json()
            self.access_token = token_data["access_token"]
            self.token_expiry = time.time() + token_data["expires_in"] - 300  # 5 min buffer
            
            expires_str = time.strftime("%Y-%m-%d %H:%M:%S", 
                                      time.localtime(self.token_expiry))
            print(f"✓ Token obtained - expires {expires_str}")
            
            return self.access_token
            
        except Exception as e:
            print(f"❌ Authentication failed: {e}")
            sys.exit(1)
    
    def safe_get(self, data: Dict, path: str, default: Any = None) -> Any:
        """Safely get nested dictionary values."""
        try:
            keys = path.split('.')
            result = data
            for key in keys:
                if isinstance(result, dict) and key in result:
                    result = result[key]
                else:
                    return default
            return result
        except:
            return default
    
    def get_source_platform(self, opp_type: str) -> str:
        """Determine the source platform based on opportunity type."""
        platform_mapping = {
            "FBO": "SAM.gov",
            "OPP": "Deltek Tracked",
            "TNS": "Task Orders (TOONS)",
            "BID": "State/Local Bids",
            "TOP": "Opportunity Manager"
        }
        return platform_mapping.get(opp_type, "Unknown")
    
    def is_sam_gov_opportunity(self, opp: Dict) -> bool:
        """Check if opportunity is from SAM.gov."""
        return self.safe_get(opp, "type") == "FBO"
    
    def extract_opportunity_data(self, opp: Dict) -> Dict:
        """Extract all relevant data from an opportunity, handling missing fields gracefully."""
        # Determine source platform
        opp_type = self.safe_get(opp, "type")
        source_platform = self.get_source_platform(opp_type)
        
        extracted = {
            # Basic Information
            "opportunity_id": self.safe_get(opp, "id"),
            "iq_opp_id": self.safe_get(opp, "iqOppId"),
            "title": self.safe_get(opp, "title"),
            "status": self.safe_get(opp, "status"),
            "type": opp_type,
            "source_platform": source_platform,
            "internal_status": self.safe_get(opp, "internalStatus"),
            
            # Dates
            "created_date": self.safe_get(opp, "createdDate"),
            "update_date": self.safe_get(opp, "updateDate"),
            "solicitation_date": self.safe_get(opp, "solicitationDate.value"),
            "response_date": self.safe_get(opp, "responseDate"),
            "award_date": self.safe_get(opp, "awardDate"),
            "termination_date": self.safe_get(opp, "terminationDateTx"),
            
            # Solicitation Information
            "solicitation_number": self.safe_get(opp, "solicitationNumber"),
            "source_url": self.safe_get(opp, "sourceURL"),
            
            # Financial Information
            "opp_value": self.safe_get(opp, "oppValue"),
            "opp_value_canada": self.safe_get(opp, "oppValueCanada"),
            "plan_price_tx": self.safe_get(opp, "planPriceTx"),
            "plan_price_canadian": self.safe_get(opp, "planPriceCanadian"),
            "fed_prime_obligation_amt": self.safe_get(opp, "fedPrimeObligationAmt"),
            "revenue": self.safe_get(opp, "revenue"),
            
            # Government Entity
            "gov_entity_id": self.safe_get(opp, "govEntity.id"),
            "gov_entity_title": self.safe_get(opp, "govEntity.title"),
            "gov_type": self.safe_get(opp, "govType"),
            
            # Classification and Requirements
            "primary_naics_id": self.safe_get(opp, "primaryNAICS.id"),
            "primary_naics_title": self.safe_get(opp, "primaryNAICS.title"),
            "primary_naics_size_standard": self.safe_get(opp, "primaryNAICS.sizeStandard"),
            "classification_code_desc": self.safe_get(opp, "classificationCodeDesc"),
            "primary_requirement": self.safe_get(opp, "primaryRequirement"),
            "procurement": self.safe_get(opp, "procurement"),
            
            # Competition and Contract Information
            "competition_types": [],
            "contract_types": [],
            "additional_naics": [],
            
            # Location and Performance
            "country": self.safe_get(opp, "country"),
            "city": self.safe_get(opp, "city"),
            "zip": self.safe_get(opp, "zip"),
            
            # Description and Duration
            "description": self.safe_get(opp, "description"),
            "duration": self.safe_get(opp, "duration"),
            
            # Security and Business Requirements
            "capabilities": self.safe_get(opp, "capabilities"),
            "cage_code": self.safe_get(opp, "cageCode"),
            "cmmc_requirements": self.safe_get(opp, "cmmcRequirements"),
            "socio_economic_status": self.safe_get(opp, "socioEconomicStatus"),
            "small_bus_naics": self.safe_get(opp, "smallBusNaics"),
            "org_certification": self.safe_get(opp, "orgCertification"),
            "org_facility_clearance": self.safe_get(opp, "orgFacilityClearance"),
            "org_staff_clearance": self.safe_get(opp, "orgStaffClearance"),
            
            # Estimates and Flags
            "is_deltek_estimate": self.safe_get(opp, "isDeltekEstimate"),
            "priority": self.safe_get(opp, "priority"),
            
            # Award Information
            "type_of_award": self.safe_get(opp, "typeOfAward"),
            "exclusion_type": self.safe_get(opp, "exclusionTypeTx"),
            
            # Partner Information
            "partner_response_date": self.safe_get(opp, "partnerResponseDate"),
            
            # Links
            "web_href": self.safe_get(opp, "links.webHref.href"),
        }
        
        # Extract competition types
        comp_types = self.safe_get(opp, "competitionTypes", [])
        if comp_types:
            extracted["competition_types"] = [
                {
                    "id": self.safe_get(comp, "id"),
                    "title": self.safe_get(comp, "title")
                }
                for comp in comp_types
            ]
        
        # Extract contract types
        contract_types = self.safe_get(opp, "contractTypes", [])
        if contract_types:
            extracted["contract_types"] = [
                {
                    "id": self.safe_get(cont, "id"),
                    "title": self.safe_get(cont, "title")
                }
                for cont in contract_types
            ]
        
        # Extract additional NAICS
        add_naics = self.safe_get(opp, "additionalNaics", [])
        if add_naics:
            extracted["additional_naics"] = [
                {
                    "id": self.safe_get(naics, "id"),
                    "title": self.safe_get(naics, "title"),
                    "size_standard": self.safe_get(naics, "sizeStandard")
                }
                for naics in add_naics
            ]
        
        return extracted
    
    def search_personnel_security_opportunities(self, 
                                              last_hours: int = 24,
                                              max_results: int = 100,
                                              include_naics: List[str] = None,
                                              include_psc: List[str] = None) -> Dict:
        """
        Search for personnel security opportunities from the last N hours.
        
        Args:
            last_hours: Number of hours to look back (default: 24)
            max_results: Maximum results per page (default: 100, max: 100)
            include_naics: Optional list of NAICS codes to include
            include_psc: Optional list of PSC codes to include
        """
        token = self.get_access_token()
        
        # Build search parameters
        params = {
            "q": '"personnel security"',  # Exact phrase search
            "oppSelectionDateFrom": f"-{last_hours}H",  # Relative date format
            "oppCategory": 2,  # New and Update
            "max": min(max_results, 100),  # API limit is 100
            "offset": 0,
        }
        
        # Add optional NAICS codes
        if include_naics:
            params["naics"] = ",".join(include_naics)
        
        # Add optional PSC codes  
        if include_psc:
            params["classificationCodes"] = ",".join(include_psc)
        
        try:
            response = requests.get(
                self.search_url,
                headers={"Authorization": f"Bearer {token}"},
                params=params,
                timeout=30,
            )
            
            if response.status_code != 200:
                raise Exception(f"Search failed {response.status_code}: {response.text}")
            
            data = response.json()
            total_count = self.safe_get(data, "meta.paging.totalCount", 0)
            
            print(f"✓ Found {total_count} personnel security opportunities")
            
            # Extract detailed data from each opportunity
            opportunities = []
            for opp in data.get("opportunities", []):
                extracted_opp = self.extract_opportunity_data(opp)
                opportunities.append(extracted_opp)
            
            return {
                "search_metadata": {
                    "search_time": datetime.now().isoformat(),
                    "total_count": total_count,
                    "returned_count": len(opportunities),
                    "search_parameters": params,
                    "hours_back": last_hours
                },
                "opportunities": opportunities
            }
            
        except Exception as e:
            print(f"❌ Search failed: {e}")
            return {
                "search_metadata": {
                    "search_time": datetime.now().isoformat(),
                    "error": str(e),
                    "search_parameters": params
                },
                "opportunities": []
            }
    
    def get_all_recent_opportunities(self, last_hours: int = 24) -> List[Dict]:
        """
        Get all personnel security opportunities from the last N hours,
        handling pagination if necessary.
        """
        all_opportunities = []
        offset = 0
        max_per_page = 100
        
        while True:
            token = self.get_access_token()
            
            params = {
                "q": '"personnel security"',
                "oppSelectionDateFrom": f"-{last_hours}H",
                "oppCategory": 2,
                "max": max_per_page,
                "offset": offset,
            }
            
            try:
                response = requests.get(
                    self.search_url,
                    headers={"Authorization": f"Bearer {token}"},
                    params=params,
                    timeout=30,
                )
                
                if response.status_code != 200:
                    print(f"❌ Pagination request failed: {response.status_code}")
                    break
                
                data = response.json()
                opportunities = data.get("opportunities", [])
                
                if not opportunities:
                    break
                
                # Extract data from this page
                for opp in opportunities:
                    extracted_opp = self.extract_opportunity_data(opp)
                    all_opportunities.append(extracted_opp)
                
                # Check if we got all results
                total_count = self.safe_get(data, "meta.paging.totalCount", 0)
                if len(all_opportunities) >= total_count:
                    break
                    
                offset += max_per_page
                print(f"📄 Retrieved {len(all_opportunities)}/{total_count} opportunities...")
                
                # Add a small delay to respect rate limits
                time.sleep(0.1)
                
            except Exception as e:
                print(f"❌ Pagination error: {e}")
                break
        
        return all_opportunities

def main():
    """Main execution function for testing."""
    api = GovWinAPI()
    
    print("🔍 Searching for personnel security opportunities from last 24 hours...")
    
    # Get opportunities with common NAICS codes for personnel security
    personnel_security_naics = [
        "541611",  # Administrative Management and General Management Consulting Services
        "561611",  # Investigation, Guard, and Armored Car Services
        "541214",  # Payroll Services
    ]
    
    personnel_security_psc = [
        "R408",  # Support- Professional: Program Management/Support Services
        "R703",  # Support- Professional: Other Safety and Security Services
    ]
    
    result = api.search_personnel_security_opportunities(
        last_hours=24,
        max_results=100,
        # include_naics=personnel_security_naics,
        # include_psc=personnel_security_psc
    )
    
    # Print summary
    print(f"\n📊 Search Summary:")
    print(f"   Total opportunities found: {result['search_metadata'].get('total_count', 0)}")
    print(f"   Opportunities retrieved: {result['search_metadata'].get('returned_count', 0)}")
    
    # Print first few opportunities with key details
    if result["opportunities"]:
        print(f"\n📋 Sample Opportunities:")
        for i, opp in enumerate(result["opportunities"][:5], 1):
            print(f"\n   {i}. {opp.get('title', 'No Title')}")
            print(f"      ID: {opp.get('opportunity_id', 'N/A')}")
            print(f"      Source: {opp.get('source_platform', 'N/A')} (Type: {opp.get('type', 'N/A')})")
            print(f"      Status: {opp.get('status', 'N/A')}")
            print(f"      Value: ${opp.get('opp_value', 'N/A')}")
            print(f"      Gov Entity: {opp.get('gov_entity_title', 'N/A')}")
            print(f"      Solicitation #: {opp.get('solicitation_number', 'N/A')}")
            if opp.get('solicitation_date'):
                print(f"      Solicitation Date: {opp.get('solicitation_date', 'N/A')}")
            if opp.get('response_date'):
                print(f"      Response Date: {opp.get('response_date', 'N/A')}")
    
    # Print source breakdown
    if result["opportunities"]:
        source_counts = {}
        for opp in result["opportunities"]:
            source = opp.get('source_platform', 'Unknown')
            source_counts[source] = source_counts.get(source, 0) + 1
        
        print(f"\n📊 Source Platform Breakdown:")
        for source, count in source_counts.items():
            print(f"   {source}: {count} opportunities")
    
    # Save to JSON file with timestamp
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    filename = f"personnel_security_opportunities_{timestamp}.json"
    
    with open(filename, 'w', encoding='utf-8') as f:
        json.dump(result, f, indent=2, ensure_ascii=False, default=str)
    
    print(f"\n💾 Results saved to: {filename}")
    
    return result

if __name__ == "__main__":
    # Example usage for serverless function
    result = main()
# Out:
# 🔍 Searching for personnel security opportunities from last 24 hours...
# ✓ Token obtained - expires 2025-06-12 02:55:53
# ✓ Found 7 personnel security opportunities
#
# 📊 Search Summary:
#    Total opportunities found: 7
#    Opportunities retrieved: 7
#
# 📋 Sample Opportunities:
#
#    1. FIELD BACKGROUND INVESTIGATIVE SERVICES
#       ID: OPP255515
#       Source: Unknown (Type: trackedopp)
#       Status: Post-RFP
#       Value: $0
#       Gov Entity: OFFICE OF PROFESSIONAL RESPONSIBILITY AND SECURITY OPERATIONS
#       Solicitation #: 15A00025R00000040
#       Solicitation Date: 2025-06-11T00:00:00.000
#
#    2. SECURITY PROCESSING SUPPORT SERVICES (SPSS)
#       ID: OPP248848
#       Source: Unknown (Type: trackedopp)
#       Status: Pre-RFP
#       Value: $0
#       Gov Entity: ASST SECRETARY FOR ADMINISTRATION
#       Solicitation #: 75P00125R00002
#       Solicitation Date: 2025-09-30T00:00:00.000
#
#    3. ICE OFFICE OF PROFESSIONAL RESPONSIBILITY TECHNOLOGY SOLUTIONS
#       ID: OPP245230
#       Source: Unknown (Type: trackedopp)
#       Status: Pre-RFP
#       Value: $0
#       Gov Entity: IMMIGRATION AND CUSTOMS ENFORCEMENT
#       Solicitation #:
#       Solicitation Date: 2025-09-11T00:00:00.000
#
#    4. DOMAIN LOGISTICS SUPPORT FOR THE CENTER FOR EXPLOSIVE ORDNANCE DISPOSAL AND DIVING AT NAVAL SUPPORT ACTIVITY NSA PANAMA CITY FL
#       ID: OPP247490
#       Source: Unknown (Type: trackedopp)
#       Status: Pre-RFP
#       Value: $0
#       Gov Entity: FLEET LOGISTICS CENTER JACKSONVILLE
#       Solicitation #: N6883625R0002
#       Solicitation Date: 2025-08-29T00:00:00.000
#
#    5. ELECTROMAGNETIC SPECTRUM ENGINEERING ANALYSIS AND SERVICES (EMS EAS)
#       ID: OPP243743
#       Source: Unknown (Type: trackedopp)
#       Status: Pre-RFP
#       Value: $50000
#       Gov Entity: DEFENSE SPECTRUM ORGANIZATION / JOINT SPECTRUM CENTER
#       Solicitation #: 632469687
#       Solicitation Date: 2025-09-23T00:00:00.000
#
# 📊 Source Platform Breakdown:
#    Unknown: 7 opportunities
#
# 💾 Results saved to: personnel_security_opportunities_20250611_160209.json
